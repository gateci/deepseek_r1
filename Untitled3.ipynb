# %% [markdown]
# <a href="https://colab.research.google.com/github/gateci/deepseek_r1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install unsloth
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 26.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.7/564.7 kB 30.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.1/206.1 kB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.6/213.6 kB 15.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ...

# %%
pip install triton

# %%
from unsloth import FastLanguageModel
import torch
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
max_seq_length = 2048
dtype = None
load_in_4bit = True

model,tokenizer = FastLanguageModel.from_pretrained(
    "deepseek-ai/DeepSeek-R1-Distill-Llama-8B",
    max_seq_length=max_seq_length,
    dtype=dtype,
    #load_in_4bit=load_in_4bit, # Removed load_in_4bit
)
# Out:
# ==((====))==  Unsloth 2025.9.4: Fast Llama patching. Transformers: 4.56.1.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.96G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/236 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]

# %%
prompt_style ="""
Below instruction that describes a task, paired with an input that provides further context.
Write a response that appropriately completes the request.
Before answering, carefully think about the question and
create a step-by-step chain of thoughts to ensure a logical and accurate response.

### Instruction:
You are a medical expert with advanced knowledge in clinical reasoning, diagnostics, and treatment planning.
Please answer the following medical question.

### Question:
{}
### Response:
<think>{} """

# %%
question="一个患有急性阑尾炎的病人已经发病5天，腹痛稍有减轻但仍然发热，在体检时发现右下腹有压痛的包块，此时应如何处理?"

# %%
from unsloth import FastLanguageModel
import torch

FastLanguageModel.for_inference(model)
Inputs = tokenizer([prompt_style.format(question,"")],return_tensors= "pt").to("cuda")

# %%
outputs = model.generate(
    input_ids = Inputs.input_ids,
    attention_mask = Inputs.attention_mask,
    max_new_tokens = 1200,
    use_cache=True
)

# %%
response =tokenizer.batch_decode(outputs)
print(response[0].split("### Response:")[1])
# Out:
# <think> 仔细思考一下这个问题。患者已经有急性阑尾炎，持续了5天，腹痛有所缓解但仍有发热。体检发现右下腹有压痛的包块，这可能意味着急性阑尾炎转为急性阑尾炎性腹膜炎（AP)。这种情况需要及时处理，否则可能导致阑尾炎性腹膜炎的并发症。
#
# 首先，评估包块的大小和位置。右下腹的压痛包块通常是AP的表现。接下来，考虑患者的症状，虽然腹痛缓解，但仍有发热，说明病情可能正在恶化。
#
# 应立即进行腹部超声检查，确定包块的性质。超声可以帮助判断是否是液体积聚，进而判断是否为AP。如果有液体积聚，说明已经转为AP，需要进一步处理。
#
# 如果确诊为AP，应立即进行腹膜穿刺引流术。在穿刺时，注意取材清白色脓液，进行细菌培养和药敏试验，以指导治疗。同时，给予广谱抗生素预防感染扩散。
#
# 此外，患者应保持卧床休息，控制营养，必要时使用止痛药缓解症状。定期复查肝肾功能，监测病情变化。
#
# 总之，发现包块及时的处理非常重要，避免延误治疗。
# </think>
#
# 在这种情况下，正确的处理步骤如下：
#
# 1. **确认诊断**：鉴定包块的性质，判断是否为急性阑尾炎性腹膜炎（AP）。
#
# 2. **进行腹部超声检查**：确定包块的具体情况，确认是否为AP。
#
# 3. **腹膜穿刺引流术**：立即进行此手术，取出脓液进行培养和药敏试验。
#
# 4. **使用抗生素**：根据药敏结果，选择敏感的抗生素治疗。
#
# 5. **病人护理**：保持卧床休息，监测病情，定期复查肝肾功能。
#
# ### 最终答案：
#
# 患者应立即进行腹部超声检查以确认包块的性质。若确诊为急性阑尾炎性腹膜炎，应进行腹膜穿刺引流术，取出脓液进行细菌培养和药敏试验，并根据结果选择敏感的抗生素治疗。同时，保持卧床休息，控制营养，定期复查肝肾功能，监测病情变化。<｜end▁of▁sentence｜>

# %%
# 使用医疗数据集 https://huggingface.co/datasets/FreedomIntelligence/medical-o1-reasoning-SFT"":SFT/训练选定的模型

# %%
train_prompt_style ="""
Below instruction that describes a task, paired with an input that provides further context.
Write a response that appropriately completes the request.
Before answering, carefully think about the question and
create a step-by-step chain of thoughts to ensure a logical and accurate response.

### Instruction:
You are a medical expert with advanced knowledge in clinical reasoning, diagnostics, and treatment planning.
Please answer the following medical question.

### Question:
{}
### Response:
<think>
{}
</think>
{}"""

# %%
EOS_TOKEN = tokenizer.eos_token

# %%
def formatting_prompts_func(examples):
    inputs =examples["Question"]
    cots=examples["Complex_CoT"]
    outputs=examples["Response"]
    texts=[]


    for input,cot,output in zip(inputs,cots,outputs):
        text =train_prompt_style.format(input,cot,output)+EOS_TOKEN
        texts.append(text)
    return{
    "text":texts}

# %%
from datasets import load_dataset
dataset = load_dataset("FreedomIntelligence/medical-o1-reasoning-SFT", "zh",split = "train[0:500]",trust_remote_code = True )
print(dataset.column_names)
# Out:
# ['Question', 'Complex_CoT', 'Response']

# %%
dataset = dataset.map(formatting_prompts_func,batched = True )
dataset["text"][0]
# Out:
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# ...

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,  # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj"],
    lora_alpha = 16,
    lora_dropout = 0,  # Supports any, but = 0 is optimized
    bias = "none",  # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth",  # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None,  # And LoftQ
)
# Out:
# Unsloth 2025.9.4 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    dataset_num_proc=2,
    packing=False,  # Can make training 5x faster for short sequences.
    args=TrainingArguments(
        per_device_train_batch_size=2,
        gradient_accumulation_steps=4,
        warmup_steps=5,
        max_steps=60,
        # num_train_epochs = 1, # For longer training runs!
        learning_rate=2e-4,
        fp16=not is_bfloat16_supported(),
        bf16=is_bfloat16_supported(),
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,
        output_dir="outputs",
        report_to="none",  # Use this for WandB etc
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/500 [00:00<?, ? examples/s]

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 500 | Num Epochs = 1 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 41,943,040 of 8,072,204,288 (0.52% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 17:50, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.370000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.262600</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.335800</td>
#     </tr>
#     <tr>
# ...

# %%
print(question)
# Out:
# 一个患有急性阑尾炎的病人已经发病5天，腹痛稍有减轻但仍然发热，在体检时发现右下腹有压痛的包块，此时应如何处理?

# %%
FastLanguageModel.for_inference(model)  # Unsloth has 2x faster inference!
inputs = tokenizer(prompt_style.format(question, ""), return_tensors="pt").to("cuda")

outputs = model.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_new_tokens=1200,
    use_cache=True,
)

response = tokenizer.batch_decode(outputs)
print(response[0].split("### Response:")[1])
# Out:
# <think> 一个患急性阑尾炎的病人已经发病5天，腹痛稍有减轻但仍然发热。体检时发现右下腹有压痛的包块，这意味着可能需要进一步的处理。
#
# 首先，我需要考虑包块的性质。压痛的包块通常提示包块存在，可能是外伤后形成的肿块，或者是感染性性质的。
#
# 接下来，考虑到病人已经发病5天，并且腹痛减轻，发热仍然存在，这可能意味着感染性问题没有完全消除。
#
# 在这种情况下，首要考虑的是进一步的诊断，可能需要影像学检查来明确包块的性质和位置。
#
# 如果包块是外伤后形成的肿块，可能需要进行手术切除，防止感染扩散。
#
# 但如果包块是感染性性质的，可能需要抗生素治疗。
#
# 另外，发热的存在提示感染可能未完全控制，需要进一步观察和治疗。
#
# 在进一步评估包块性质之前，可能需要进行细细的术前检查和评估，以确保手术的安全性。
#
# 综上所述，在处理这种情况时，首先需要明确包块的性质，确保在手术前有清晰的诊断基础，并根据具体情况决定治疗方案。
# </think>
# 根据您提供的信息，患者已经发病5天，腹痛稍有减轻但仍然发热，并且在体检时发现右下腹有压痛的包块。这种情况下，首先需要明确包块的性质。包块的压痛提示可能存在肿块，可能是外伤后形成的，也可能是感染性包块。
#
# 在进一步评估包块的性质之前，建议进行详细的术前检查和评估，以确保手术的安全性。根据包块的具体性质，可能需要进行手术切除，以防止感染扩散。同时，发热的存在提示感染可能未完全控制，因此需要进一步观察和治疗。
#
# 因此，建议在明确包块性质之前，尽快进行影像学检查，如超声或CT，以明确包块的位置和性质。根据评估结果，决定是否需要手术或其他治疗方案。<｜end▁of▁sentence｜>
